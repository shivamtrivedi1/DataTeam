# %%
import boto3

client = boto3.client('s3')

# %% [markdown]
# # Get all files in a bucket with Session Method

# %%
from boto3.session import Session
ACCESS_KEY='AKIAQ7CTZ57UNXN7ZSL3'
SECRET_KEY='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'
session = Session(aws_access_key_id=ACCESS_KEY, aws_secret_access_key=SECRET_KEY,region_name='ap-south-1')
s3 = session.resource('s3')
your_bucket = s3.Bucket('uup-uat-cpp-tdt1')
for s3_file in your_bucket.objects.all():
    print(s3_file.key)
# Out:
# persona_dict/
# persona_dict_1/persona_dict/_SUCCESS
# persona_dict_1/persona_dict/part-00000
# persona_dict_1/persona_dict/part-00001
# persona_dict_1/persona_dict/part-00002
# persona_dict_1/persona_dict/part-00003
# persona_dict_1/persona_dict/part-00004
# persona_dict_1/persona_dict/part-00005
# persona_dict_1/persona_dict/part-00006
# persona_dict_1/persona_dict/part-00007
# persona_dict_1/persona_dict/part-00008
# persona_dict_1/persona_dict/part-00009
# persona_dict_1/persona_dict/part-00010
# persona_dict_1/persona_dict/part-00011
# persona_dict_1/persona_dict/part-00012
# persona_dict_1/persona_dict/part-00013
# persona_dict_1/persona_dict/part-00014
# persona_dict_1/persona_dict/part-00015
# persona_dict_1/persona_dict/part-00016
# persona_dict_1/persona_dict/part-00017
# persona_dict_1/persona_dict/part-00018
# persona_dict_1/persona_dict/part-00019
# persona_dict_1/persona_dict/part-00020
# persona_dict_1/persona_dict/part-00021
# persona_dict_1/persona_dict/part-00022
# ...

# %% [markdown]
# # Get all buckets

# %%
for each_bu in s3.buckets.all():
    print(each_bu.name)
# Out:
# amplify-smartocr-dev-90750-deployment
# attributedatavalidation
# aws-a2i-bucket
# aws-athena-query-results-066747756520-ap-southeast-1
# aws-athena-query-results-ap-south-1-066747756520
# aws-athena-query-results-us-west-2-066747756520
# aws-emr-resources-066747756520-ap-southeast-1
# aws-glue-notebooks-066747756520-ap-south-1
# aws-glue-scripts-066747756520-ap-south-1
# aws-glue-scripts-066747756520-ap-southeast-1
# aws-glue-scripts-066747756520-us-east-1
# aws-glue-scripts-066747756520-us-east-2
# aws-glue-temporary-066747756520-ap-south-1
# aws-glue-temporary-066747756520-ap-southeast-1
# aws-glue-temporary-066747756520-us-east-1
# aws-glue-temporary-066747756520-us-east-2
# aws-logs-066747756520-ap-northeast-2
# aws-logs-066747756520-ap-south-1
# aws-logs-066747756520-ap-southeast-1
# aws-logs-066747756520-us-east-1
# aws-logs-066747756520-us-east-2
# aws-sam-cli-managed-default-samclisourcebucket-1othkaq960c4n
# aws-sam-cli-managed-default-samclisourcebucket-edr49rxyqb01
# ...

# %%
client = session.client('ecs')
cluster = client.list_clusters()
clusterArns = cluster["clusterArns"]
print(clusterArns)
for i in clusterArns:
    print(i.split('/')[1])
# Out:
# ['arn:aws:ecs:ap-south-1:066747756520:cluster/autoseg-dev']
# autoseg-dev

# %%
response = client.list_task_definitions(
)

print(response)
# Out:
# {'taskDefinitionArns': ['arn:aws:ecs:ap-south-1:066747756520:task-definition/autoseg-dev:1'], 'ResponseMetadata': {'RequestId': 'b13a2a1d-32d0-44ca-adb9-7ea82c1dc358', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'b13a2a1d-32d0-44ca-adb9-7ea82c1dc358', 'content-type': 'application/x-amz-json-1.1', 'content-length': '92', 'date': 'Mon, 27 Sep 2021 05:27:13 GMT'}, 'RetryAttempts': 0}}

# %%
response = client.list_tasks(
    cluster='autoseg-dev',
)

print(response)
# Out:
# {'taskArns': [], 'ResponseMetadata': {'RequestId': '28064d2c-3ac1-4c70-91a7-cbe5f3487e2c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '28064d2c-3ac1-4c70-91a7-cbe5f3487e2c', 'content-type': 'application/x-amz-json-1.1', 'content-length': '15', 'date': 'Mon, 27 Sep 2021 05:46:12 GMT'}, 'RetryAttempts': 0}}

# %%
import boto3
response = client.run_task(
    cluster='autoseg-dev',
    taskDefinition='autoseg-dev:1',
)

print(response)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterException                 Traceback (most recent call last)
# <ipython-input-15-ebdf2be33dfc> in <module>
#       1 import boto3
# ----> 2 response = client.run_task(
#       3     cluster='autoseg-dev',
#       4     taskDefinition='autoseg-dev:1',
#       5 )
#
# b:\datascience\datascience\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     384                     "%s() only accepts keyword arguments." % py_operation_name)
#     385             # The "self" in this scope is referring to the BaseClient.
# --> 386             return self._make_api_call(operation_name, kwargs)
#     387
#     388         _api_call.__name__ = str(py_operation_name)
#
# b:\datascience\datascience\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     703             error_code = parsed_response.get("Error", {}).get("Code")
# ...

# %%
response = client.list_clusters(
)

print(response)
# Out:
# {'clusterArns': ['arn:aws:ecs:ap-south-1:066747756520:cluster/autoseg-dev'], 'ResponseMetadata': {'RequestId': '99eeb2dd-8c18-4f2e-b96d-92a8d224a67d', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '99eeb2dd-8c18-4f2e-b96d-92a8d224a67d', 'content-type': 'application/x-amz-json-1.1', 'content-length': '75', 'date': 'Mon, 27 Sep 2021 06:13:49 GMT'}, 'RetryAttempts': 0}}
